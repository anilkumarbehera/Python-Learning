# %%
print("Hello world")
# Out:
# Hello world

# %%
print(hello world)
# Out:
#   Cell In[2], line 1
#     print(hello world)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# ### in the print function what ever the data types you will pass that will print same.

# %%
print("Hello", 1, 4.5, True)
# Out:
# Hello 1 4.5 True

# %% [markdown]
# ###### print() where when you pause sometime and you will see () then manual pop up will come i.e known as Reading Manual

# %%
print("hello", 1, True, sep='/')
# Out:
# hello/1/True

# %% [markdown]
# ### \n means Line change

# %%
print("hello", 1, True, 1.2)
# Out:
# hello 1 True 1.2

# %%
print('anil', end='-')
print("kumar")
# Out:
# anil-kumar

# %% [markdown]
# ### DataTypes -  a language that can work with how many types with different kind of data

# %%
# integer
print(8)

print(1e309) ## this is the max number that python will print infinity
print(1e308)
# Out:
# 8
# inf
# 1e+308

# %%
# decimal
print(8.55)
print(1.7e309) ## this is the max float number that you can print
# Out:
# 8.55
# inf

# %%
## boolean
print(True)
# Out:
# True

# %%
# string
print("Anil kumar")
# Out:
# Anil kumar

# %%
#complex
print(5+6j)
# Out:
# (5+6j)

# %%
#list
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
#tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
##sets
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
#dictionary
print({"name":"Anil"})
# Out:
# {'name': 'Anil'}

# %%
#type
type(2)  #int
type(3.5)  #float
type(True)  #boolean
type('Anil')
# Out:
# str

# %% [markdown]
# #### Variables - is the one kind of container where you can store the values for future

# %%
name = 'Anil'
print(name)

a = 1
b = 2
print(a+b)
# Out:
# Anil
# 3

# %%
### What is Dynamic Typing - You don't tell the data type of the variable, Interpreter understand it what is the data type
a = 5
# you should not tell to python that a is the integer type

# %%
## Dynamic Binding
a = 5
print(a)

a= "anil"
print(a)
# Out:
# 5
# anil

# %%
a,b,c = 1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
a=b=c =5
print(a,b,c)
# Out:
# 5 5 5

# %%
## keywords & identifiers (These are the reserve word store inside  Python to intrprter convert from High level code to machine readeable code)

# %%
## Identifiers
#1. you cann't start with a digit
name1 = 'Anil'
print(name1)

# 2. You can use special chars like underscore(_)

first_name = 'Anil'
print(first_name)

# identifiers can't be keyword
# Out:
# Anil
# Anil

# %% [markdown]
# ##### Take user input

# %%
a = input('Enter your first name')
b = input('enter your last name')

print(a,b)
# Out:
# ak b

# %%
a = input('Enter first number')
b = input('enter second number')

c = a+b

print(c)
# Out:
# 55

# %% [markdown]
# Type converstion

# %%
print(5+5.6)
print(type(5), type(5.5))
# Out:
# 10.6
# <class 'int'> <class 'float'>

# %%
a = input("enter a number")
b = input("enter second number")

c = int(a) + int(b)
print(c)
print(type(a))
# Out:
# 10
# <class 'str'>

# %%
a = int(input("enter a number"))
b = int(input("enter second number"))
c = a+b
print(c)
print(type(a))
# Out:
# 10
# <class 'int'>
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### python type conversion doesn't change the data it create a new value

# %% [markdown]
# ### Literals - what ever the values that you store inside the variable i.e literals
